# %% [markdown]
# # Integ 475- Tumblr Network Project

# %% [markdown]
# ### Getting Started

# %%
# Import relevant programs and functions

import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import string
import re

# %%
# Assigns variable "url" to url of post 
# Assigns variable "urlhandle" to url of post's source blog (obtained from post url using regex)
# Post's url is accessed, and the content turned into a BeautifulSoup object 
# From here, all content held within "ol" (ordered list) tags is located and added to the list 'sections2' 
# (There should only be one item this list)
# Next, all content found within "li" (list item) tags from the 'ordered list' string is added to the list "sections"
# Each element in "sections" is a 'note' (a like/reblog of the post)

url = "http://eurosong.tumblr.com/post/160511885918/good-afternoon-folks-and-welcome-to-todays"  
urlhandle = (re.findall('http[s]*://[A-Za-z-]+\.tumblr\.com/', url))[0] 

html = urlopen(url)
content = BeautifulSoup(html,"html5lib")                               
sections2 = content.findAll("ol")
sections=sections2[0].findAll("li")

# %% [markdown]
# ### Scrapping all the Notes

# %% [markdown]
# When a user opens a post's webpage, they will not be able to see all the post's notes right away. They will only see 50.
#
# While not available on every blog, most blogs will, however, have a feature that allows you to see beyond these inital 50 notes.
# By clicking "See More Notes", the page will update with 50 more notes that it extracted from another webpage. By clicking this option repeatedly, you will get increasingly more notes until you reach a maximum. This maximum, appears to vary by both post and by blog.
#
# While the additional notes are visible on the user end, the information will not update in the source code. To scrape these additional notes, one has to access the other webpage the original page extracted information from.

# %% [markdown]
# ### Each element in sections, has a certain number of items held in "a" tags based on what type of note it codes for:
#     # 1 = Not actually a note, but an option to "Show More Notes"
#     # 2 = A like or a line stating "Username posted this" (this only appears once and only as the last note)
#     # 3 = A reblog with no comment
#     # 4 = A reblog with a comment

# %%
x= sections[-1].findAll("a") # Creates a list of all elements held in "a" tags for the last note

# It is important to note that is the length of list "x" is 1, then it was not a note but rather an option to "Show More Notes"
# By continuously checking for this and adding the notes on the webpage it leads to to our list, we can extract the maxmimum number of notes

while len(x)==1: 
    y=str(x[0])
    y= (re.findall('notes/[0-9]+/[A-Za-z0-9]+\?from_c=[0-9]+', y))[0] #Uses regex to find the url to the webpage that contains the additional notes
    nextpage= urlhandle+y
    
    html=urlopen(nextpage)
    content=BeautifulSoup(html,"html5lib")
    sectionsnext=content.findAll("li")
    
    if len(sectionsnext)>0: #Occasionally, a page will include a "Show More Notes" option when none are available. 
                            # By making sure we actually extracted content from the new page (if len(sectionsnext) > 0)
                            # We make sure we don't create an error trying to call elements that don't exist
                
        x=sectionsnext[-1].findAll("a")
        
        for i in range(len(sectionsnext)): # All notes from the new list are added to the original list
            sections.append(sectionsnext[i]) # And the cycle repeats until the last note in our list finally has 2 elements in contained in "a" tags
                                             # Meaning (since its the very last item) it is the "Username posted this" line
            
    else:
        x=[]
    
    continue

# %%
for i in range(len(sections)):
    x=sections[i].findAll("a")

# %% [markdown]
# ### Reblogs

# %%
reblogs=[]

# Creates a list of where is element is a list containing the...
# source username, source url, recipient username, recipient url, and comment content (if any) of a single reblog

for i in range(len(sections)):
    x=sections[i].findAll("a") # Checks each element in list "sections" if it has > 2 items in "a" tags (which means its a reblog)
    if len(x)>2:
        row=[]
        
        user=x[1].get_text() #By removing all the html formatting code of the 2nd item held in "a" tags, you get the recipient username
        link=x[1].attrs['href'] #By looking for content with the attribute 'href' in the 2nd item held in "a" tags, you get the recipient url
        
        user2=x[2].get_text() # Same as above, but you work with the 3rd item and get the source username and source url
        link2=x[2].attrs['href']
        
        row.append(user) # The recipient and source information is then added to the list 'row' (which will make up one row in the dataframe)
        row.append(link)
        row.append(user2)
        row.append(link2)
        
        if len(x)>3: # If there are > 3 items in "a" tags, we know a comment was added during the reblog
            comment = x[3].get_text() # This allows us to extract the comment, clean it, and append it as the 5th item in "row"
            comment= re.sub('\n+', " ", comment) #Removes excess new line characters                           
            comment = re.sub(' +', " ", comment) #Removes excess spaces   
            row.append(comment)
            
        else:
            row.append("") # If no comment was added, the string "None" is simply added as the 5th item
        
        reblogs.append(row)
        
    else:
        continue

# %%
reblogs
# Out:
# [['iriaowillwinesc',
#   'https://iriaowillwinesc.tumblr.com/',
#   'arabela25',
#   'http://arabela25.tumblr.com/',
#   'None'],
#  ['xiithdoctor',
#   'http://xiithdoctor.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['adventurenerd',
#   'http://adventurenerd.tumblr.com/',
#   'clickthing',
#   'http://clickthing.tumblr.com/',
#   'None'],
#  ['slenderboobs',
#   'http://slenderboobs.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['wherethefuckdidthisshitcomefrom',
#   'https://wherethefuckdidthisshitcomefrom.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['magrittesflamingtuba',
#   'http://magrittesflamingtuba.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['thatdysfunctionalkingdom',
#   'https://thatdysfunctionalkingdom.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['monterrang-parkin',
#   'https://monterrang-parkin.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   ' @ph0220 '],
#  ['wymanthewalrus',
#   'http://wymanthewalrus.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['alwaysfriedstudent-b07d5fd2',
#   'https://alwaysfriedstudent-b07d5fd2.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['clickthing',
#   'http://clickthing.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['canidecideonthislater',
#   'https://canidecideonthislater.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['kingkeylor',
#   'http://kingkeylor.tumblr.com/',
#   'alvaroarbeloa',
#   'http://alvaroarbeloa.tumblr.com/',
#   'None'],
#  ['mmarieto',
#   'http://mmarieto.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['portugalpirate',
#   'https://portugalpirate.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['alvaroarbeloa',
#   'http://alvaroarbeloa.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['duksisdarker',
#   'http://duksisdarker.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['gotchipoints',
#   'http://gotchipoints.tumblr.com/',
#   'imarwood',
#   'http://imarwood.tumblr.com/',
#   'None'],
#  ['givememorepeaceplease',
#   'http://givememorepeaceplease.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['musicbuttonsandcake',
#   'http://musicbuttonsandcake.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['imarwood',
#   'http://imarwood.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['lxchlxn',
#   'http://lxchlxn.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['weatherwax-poetically',
#   'https://weatherwax-poetically.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['heirofavians',
#   'http://heirofavians.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['a-promise-that-i-keep',
#   'http://a-promise-that-i-keep.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['foreverdrunkatheart',
#   'http://foreverdrunkatheart.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['gandtea',
#   'http://gandtea.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['zazial',
#   'http://zazial.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['carly-gay-jepsen',
#   'https://carly-gay-jepsen.tumblr.com/',
#   'mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'None'],
#  ['mapsontheweb',
#   'https://mapsontheweb.zoom-maps.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['saunteringvaguely',
#   'http://saunteringvaguely.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['bracarvs',
#   'https://bracarvs.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['theportugueserevert',
#   'http://theportugueserevert.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['every-good-url-is-taken',
#   'http://every-good-url-is-taken.tumblr.com/',
#   'arabela25',
#   'http://arabela25.tumblr.com/',
#   'None'],
#  ['literallynotcoolirl',
#   'https://literallynotcoolirl.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['kseniazhuk',
#   'http://kseniazhuk.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['deathatintervals',
#   'http://deathatintervals.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None'],
#  ['arabela25',
#   'http://arabela25.tumblr.com/',
#   'eurosong',
#   'http://eurosong.tumblr.com/',
#   'None']]

# %% [markdown]
# ### Finding Non-Reblog Comments

# %%
comments=[]
indexs=[]

for i in range(len(sections)):
    x=sections[i].get_text()
    text=x.split(" ")
    
    if text[1]=="said:":
        row=[]
        
        user=text[0]
        del text[:2]
        text=" ".join(text)
        text= re.sub('\n+', " ", text) #Removes excess new line characters                           
        text = re.sub(' +', " ", text) #Removes excess spaces   
    
        row.append(user)
        
        t=sections[i].findAll("a")
        url=t[1].attrs['href']
        row.append(url)
        
        row.append(text)
        
        comments.append(row)
        indexs.append(i)
        
for i in range(len(indexs)):
    del sections[indexs[i]]

# %%
comments
# Out:
# []

# %% [markdown]
# ### Finding Likes

# %%
likes=[]

for i in range(len(sections)): # For each note in sections, use findAll() to locate all content held within "a" tags
    x=sections[i].findAll("a") # If each note had two strings held within "a" tags, it is a like. 
    if len(x) ==2: 
        row=[]                      
        
        user=x[1].get_text() # Removes html formatting code from the 2nd item held in "a" tags to get the username of the individual liking the post
        link=x[1].attrs['href'] # Looks for an item with the attribute "href" from the 2nd item held in "a" tags to get the user's blog url
        
        row.append(user) # Adds the username and url to a list named 'row' 
        row.append(link)
        
        likes.append(row) # The list 'row' is appended to the list 'likes'
        
    else:
        continue

# %%
originalposter=likes[-1] # The last element in the 'likes' list is not a like, but rather the information of the user who published the post
del likes[-1] #This information is assigned the variable 'originalposter' and then deleted from the 'likes' list

# %%
likes
# Out:
# [['notacolorfullesbian', 'https://notacolorfullesbian.tumblr.com/'],
#  ['adelina-popa', 'http://adelina.rbiz.ro/'],
#  ['myanarchistproseandpoetry',
#   'https://myanarchistproseandpoetry.tumblr.com/'],
#  ['super-rami-malek-imagines', 'http://super-rami-malek-imagines.tumblr.com/'],
#  ['danasolez', 'https://danasolez.tumblr.com/'],
#  ['paramarketing', 'https://paramarketing.tumblr.com/'],
#  ['theoldcrone', 'https://theoldcrone.tumblr.com/'],
#  ['brendabelanger', 'https://brendabelanger.tumblr.com/'],
#  ['wendijordan', 'https://wendijordan.tumblr.com/'],
#  ['subgoogle', 'https://subgoogle.tumblr.com/'],
#  ['potatoesrule4ever', 'https://potatoesrule4ever.tumblr.com/'],
#  ['tassledown', 'https://tassledown.tumblr.com/'],
#  ['linamory', 'http://linamory.tumblr.com/'],
#  ['dorkynanni', 'http://dorkynanni.tumblr.com/'],
#  ['slenderboobs', 'http://slenderboobs.tumblr.com/'],
#  ['mrfarfalle', 'https://mrfarfalle.tumblr.com/'],
#  ['claudiopompeo', 'http://claudiopompeo.tumblr.com/'],
#  ['sidsloth101', 'https://sidsloth101.tumblr.com/'],
#  ['hbbannana', 'https://hbbannana.tumblr.com/'],
#  ['scandalous-embryo', 'https://scandalous-embryo.tumblr.com/'],
#  ['wrdsmyth', 'http://wrdsmyth.tumblr.com/'],
#  ['green-217', 'http://green-217.tumblr.com/'],
#  ['meridok-old', 'http://meridok-old.tumblr.com/'],
#  ['ania-traveler-blr', 'http://ania-traveler-blr.tumblr.com/'],
#  ['lowkeylazie', 'https://lowkeylazie.tumblr.com/'],
#  ['thecakeinspace', 'http://thecakeinspace.tumblr.com/'],
#  ['icylyly', 'https://icylyly.tumblr.com/'],
#  ['corvid-shmorvid', 'https://corvid-shmorvid.tumblr.com/'],
#  ['planet-noah', 'https://planet-noah.tumblr.com/'],
#  ['monterrang-parkin', 'https://monterrang-parkin.tumblr.com/'],
#  ['wymanthewalrus', 'http://wymanthewalrus.tumblr.com/'],
#  ['swimmingweeb', 'https://swimmingweeb.tumblr.com/'],
#  ['lanceprime', 'https://lanceprime.tumblr.com/'],
#  ['beifonglover', 'http://beifonglover.tumblr.com/'],
#  ['obliviousxiv', 'http://obliviousxiv.tumblr.com/'],
#  ['gandoilfo', 'https://gandoilfo.tumblr.com/'],
#  ['eurosong', 'http://eurosong.tumblr.com/'],
#  ['alwaysfriedstudent-b07d5fd2',
#   'https://alwaysfriedstudent-b07d5fd2.tumblr.com/'],
#  ['damnsameen', 'http://damnsameen.tumblr.com/'],
#  ['ohlandeskog', 'http://ohlandeskog.tumblr.com/'],
#  ['max-armentas-random-ramblings',
#   'http://max-armentas-random-ramblings.tumblr.com/'],
#  ['cyrren', 'http://cyrren.tumblr.com/'],
#  ['rhartist13', 'https://rhartist13.tumblr.com/'],
#  ['rivster101', 'https://rivster101.tumblr.com/'],
#  ['vivillon', 'https://www.pixel.god.jp/'],
#  ['randomheresy', 'http://randomheresy.tumblr.com/'],
#  ['mayrose-amica', 'https://mayrose-amica.tumblr.com/'],
#  ['mmarieto', 'http://mmarieto.tumblr.com/'],
#  ['a-plethora-of-reasons', 'https://a-plethora-of-reasons.tumblr.com/'],
#  ['portugalpirate', 'https://portugalpirate.tumblr.com/'],
#  ['garfothedestroyer', 'https://garfothedestroyer.tumblr.com/'],
#  ['mobeika', 'https://mobeika.tumblr.com/'],
#  ['look-ahead', 'http://look-ahead.tumblr.com/'],
#  ['duksisdarker', 'http://duksisdarker.tumblr.com/'],
#  ['kitycat1', 'https://kitycat1.tumblr.com/'],
#  ['gaynozomi', 'http://gaynozomi.tumblr.com/'],
#  ['unintimidablystubborn', 'http://unintimidablystubborn.tumblr.com/'],
#  ['bitchyhideoutking', 'https://bitchyhideoutking.tumblr.com/'],
#  ['kaparaonyou', 'http://kaparaonyou.tumblr.com/'],
#  ['bumeliran', 'http://bumeliran.tumblr.com/'],
#  ['ambitionmissionplusvisionkid',
#   'http://ambitionmissionplusvisionkid.tumblr.com/'],
#  ['saltedcaramelqueer', 'http://saltedcaramelqueer.tumblr.com/'],
#  ['methoddrone', 'https://methoddrone.tumblr.com/'],
#  ['imarwood', 'http://imarwood.tumblr.com/'],
#  ['cookiesandhugs', 'https://cookiesandhugs.tumblr.com/'],
#  ['wolfofromania', 'http://wolfofromania.tumblr.com/'],
#  ['shamstack', 'http://shamstack.tumblr.com/'],
#  ['moe-thot', 'http://moe-thot.tumblr.com/'],
#  ['eurosong', 'http://eurosong.tumblr.com/'],
#  ['heirofavians', 'http://heirofavians.tumblr.com/'],
#  ['climate-changing', 'http://climate-changing.tumblr.com/'],
#  ['schniggles', 'https://schniggles.tumblr.com/'],
#  ['daisynightshade', 'http://daisynightshade.tumblr.com/'],
#  ['a-lost-boy-of-neverland', 'http://a-lost-boy-of-neverland.tumblr.com/'],
#  ['latinateoaths', 'https://latinateoaths.tumblr.com/'],
#  ['thundergyra', 'https://thundergyra.tumblr.com/'],
#  ['endlessly-dreaming-of-you', 'http://endlessly-dreaming-of-you.tumblr.com/'],
#  ['str8busta', 'http://str8busta.tumblr.com/'],
#  ['klaassein', 'http://klaassein.tumblr.com/'],
#  ['fs842', 'https://fs842.tumblr.com/'],
#  ['wobblywobbly', 'http://wobblywobbly.tumblr.com/'],
#  ['snifelisnifsnif', 'http://snifelisnifsnif.tumblr.com/'],
#  ['pearlyblue', 'http://pearlyblue.tumblr.com/'],
#  ['dianalandia', 'http://dianalandia.tumblr.com/'],
#  ['olympusrox123', 'http://olympusrox123.tumblr.com/'],
#  ['theportugueserevert', 'http://theportugueserevert.tumblr.com/'],
#  ['fairyplisetsky', 'http://fairyplisetsky.tumblr.com/'],
#  ['embracetheslash', 'http://embracetheslash.tumblr.com/'],
#  ['hyyteli', 'http://hyyteli.tumblr.com/'],
#  ['jade-sanban', 'http://jade-sanban.tumblr.com/'],
#  ['thejediviking', 'http://thejediviking.tumblr.com/'],
#  ['rupko', 'http://rupko.tumblr.com/'],
#  ['literallynotcoolirl', 'https://literallynotcoolirl.tumblr.com/'],
#  ['deathatintervals', 'http://deathatintervals.tumblr.com/'],
#  ['dreamcrazyel', 'https://dreamcrazyel.tumblr.com/'],
#  ['siannjay', 'https://siannjay.tumblr.com/'],
#  ['biazhy', 'http://biazhy.tumblr.com/']]

# %% [markdown]
# ### Creating the Like and Reblog Dataframes

# %%
df_reblog=pd.DataFrame(reblogs) # Creates the reblog dataframe
df_reblog.columns=["Recipent User", "Recipent URL", "Source User", "Source URL", "Comment"] # Assigns column titles

# %%
## Number of Reblogs
df_reblog.shape[0]
# Out:
#                      Recipent User  \
# 0                  iriaowillwinesc
# 1                      xiithdoctor
# 2                    adventurenerd
# 3                     slenderboobs
# 4  wherethefuckdidthisshitcomefrom
#
#                                         Recipent URL   Source User  \
# 0                https://iriaowillwinesc.tumblr.com/     arabela25
# 1                     http://xiithdoctor.tumblr.com/  mapsontheweb
# 2                   http://adventurenerd.tumblr.com/    clickthing
# 3                    http://slenderboobs.tumblr.com/  mapsontheweb
# 4  https://wherethefuckdidthisshitcomefrom.tumblr...  mapsontheweb
#
#                             Source URL Comment
# 0         http://arabela25.tumblr.com/    None
# 1  https://mapsontheweb.zoom-maps.com/    None
# 2        http://clickthing.tumblr.com/    None
# 3  https://mapsontheweb.zoom-maps.com/    None
# 4  https://mapsontheweb.zoom-maps.com/    None

# %%
df_likes=pd.DataFrame(likes) # Creates the likes dataframe
df_likes.columns=["Tumblr User", "Tumblr User URL"] # Assigns column titles

# %%
## Number of Likes
df_likes.shape[0]
# Out:
#                  Tumblr User                                Tumblr User URL
# 0        notacolorfullesbian        https://notacolorfullesbian.tumblr.com/
# 1               adelina-popa                        http://adelina.rbiz.ro/
# 2  myanarchistproseandpoetry  https://myanarchistproseandpoetry.tumblr.com/
# 3  super-rami-malek-imagines   http://super-rami-malek-imagines.tumblr.com/
# 4                  danasolez                  https://danasolez.tumblr.com/

# %% [markdown]
# ### Creating the Networks Dataframe

# %%
for i in range(len(reblogs)): # Each element in the 'reblogs' list is a list containing all information for one reblog 
    reblogs[i].append(1)      # Appending "1' to each reblog's list allows us to signify the existence of a reblog relationship between the source and recipient user   
    x=0
        
    for t in range(len(likes)): # For each like in the 'likes' list
    
        if reblogs[i][1]== likes[t][1]: # We check if the Tumblr user of the like matches with any of the recipient users in the reblog list
            x=1                         # If yes, the x is set to "1" (The default was 0)
            del likes[t]                # And the like is deleted from the likes list 
            break                       # Once a match is found, loop breaks and the search ends 
            
        else:
            continue 
            
    
    reblogs[i].append(x) # The "x" (which is either a 1 or 0 to signify the existence/non-existence of a like relationship) is appended to the reblog

# %%
for i in range(len(likes)): # For the Tumblr Users who didn't also reblog, we add additional information so they can be merged with the 'reblog' dataframe
   
    likes[i].append(originalposter[0])
    likes[i].append(originalposter[1])
    likes[i].append("") # Indicates that there were no comments (You cannot add a comment when you like on Tumblr)
    likes[i].append(0) # Indicates non-existence of a reblog relationship
    likes[i].append(1) # Indicates existence of a like relationship
    
    reblogs.append(likes[i])

# %%
df_network=pd.DataFrame(reblogs)

# %%
df_network.columns = ["Recipent User", "Recipent URL", "Source User", "Source URL", "Comment", "Reblog", "Like"]
df_network
# Out:
#                        Recipent User  \
# 0                    iriaowillwinesc
# 1                        xiithdoctor
# 2                      adventurenerd
# 3                       slenderboobs
# 4    wherethefuckdidthisshitcomefrom
# 5               magrittesflamingtuba
# 6           thatdysfunctionalkingdom
# 7                  monterrang-parkin
# 8                     wymanthewalrus
# 9        alwaysfriedstudent-b07d5fd2
# 10                        clickthing
# 11             canidecideonthislater
# 12                        kingkeylor
# 13                          mmarieto
# 14                    portugalpirate
# 15                     alvaroarbeloa
# 16                      duksisdarker
# 17                      gotchipoints
# 18             givememorepeaceplease
# 19               musicbuttonsandcake
# 20                          imarwood
# 21                           lxchlxn
# 22             weatherwax-poetically
# 23                      heirofavians
# 24             a-promise-that-i-keep
# 25               foreverdrunkatheart
# 26                           gandtea
# 27                            zazial
# 28                  carly-gay-jepsen
# 29                      mapsontheweb
# ..                               ...
# 93                       methoddrone
# 94                    cookiesandhugs
# 95                     wolfofromania
# 96                         shamstack
# 97                          moe-thot
# 98                          eurosong
# 99                  climate-changing
# 100                       schniggles
# 101                  daisynightshade
# 102          a-lost-boy-of-neverland
# 103                    latinateoaths
# 104                      thundergyra
# 105        endlessly-dreaming-of-you
# 106                        str8busta
# 107                        klaassein
# 108                            fs842
# 109                     wobblywobbly
# 110                  snifelisnifsnif
# 111                       pearlyblue
# 112                      dianalandia
# 113                    olympusrox123
# 114                   fairyplisetsky
# 115                  embracetheslash
# 116                          hyyteli
# 117                      jade-sanban
# 118                    thejediviking
# 119                            rupko
# 120                     dreamcrazyel
# 121                         siannjay
# 122                           biazhy
#
#                                           Recipent URL    Source User  \
# 0                  https://iriaowillwinesc.tumblr.com/      arabela25
# 1                       http://xiithdoctor.tumblr.com/   mapsontheweb
# 2                     http://adventurenerd.tumblr.com/     clickthing
# 3                      http://slenderboobs.tumblr.com/   mapsontheweb
# 4    https://wherethefuckdidthisshitcomefrom.tumblr...   mapsontheweb
# 5              http://magrittesflamingtuba.tumblr.com/   mapsontheweb
# 6         https://thatdysfunctionalkingdom.tumblr.com/   mapsontheweb
# 7                https://monterrang-parkin.tumblr.com/   mapsontheweb
# 8                    http://wymanthewalrus.tumblr.com/   mapsontheweb
# 9      https://alwaysfriedstudent-b07d5fd2.tumblr.com/       eurosong
# 10                       http://clickthing.tumblr.com/   mapsontheweb
# 11           https://canidecideonthislater.tumblr.com/   mapsontheweb
# 12                       http://kingkeylor.tumblr.com/  alvaroarbeloa
# 13                         http://mmarieto.tumblr.com/       eurosong
# 14                  https://portugalpirate.tumblr.com/       eurosong
# 15                    http://alvaroarbeloa.tumblr.com/   mapsontheweb
# 16                     http://duksisdarker.tumblr.com/   mapsontheweb
# 17                     http://gotchipoints.tumblr.com/       imarwood
# 18            http://givememorepeaceplease.tumblr.com/   mapsontheweb
# 19              http://musicbuttonsandcake.tumblr.com/   mapsontheweb
# 20                         http://imarwood.tumblr.com/   mapsontheweb
# 21                          http://lxchlxn.tumblr.com/   mapsontheweb
# 22           https://weatherwax-poetically.tumblr.com/   mapsontheweb
# 23                     http://heirofavians.tumblr.com/   mapsontheweb
# 24            http://a-promise-that-i-keep.tumblr.com/   mapsontheweb
# 25              http://foreverdrunkatheart.tumblr.com/   mapsontheweb
# 26                          http://gandtea.tumblr.com/   mapsontheweb
# 27                           http://zazial.tumblr.com/   mapsontheweb
# 28                https://carly-gay-jepsen.tumblr.com/   mapsontheweb
# 29                 https://mapsontheweb.zoom-maps.com/       eurosong
# ..                                                 ...            ...
# 93                     https://methoddrone.tumblr.com/       eurosong
# 94                  https://cookiesandhugs.tumblr.com/       eurosong
# 95                    http://wolfofromania.tumblr.com/       eurosong
# 96                        http://shamstack.tumblr.com/       eurosong
# 97                         http://moe-thot.tumblr.com/       eurosong
# 98                         http://eurosong.tumblr.com/       eurosong
# 99                 http://climate-changing.tumblr.com/       eurosong
# 100                     https://schniggles.tumblr.com/       eurosong
# 101                 http://daisynightshade.tumblr.com/       eurosong
# 102         http://a-lost-boy-of-neverland.tumblr.com/       eurosong
# 103                  https://latinateoaths.tumblr.com/       eurosong
# 104                    https://thundergyra.tumblr.com/       eurosong
# 105       http://endlessly-dreaming-of-you.tumblr.com/       eurosong
# 106                       http://str8busta.tumblr.com/       eurosong
# 107                       http://klaassein.tumblr.com/       eurosong
# 108                          https://fs842.tumblr.com/       eurosong
# 109                    http://wobblywobbly.tumblr.com/       eurosong
# 110                 http://snifelisnifsnif.tumblr.com/       eurosong
# 111                      http://pearlyblue.tumblr.com/       eurosong
# 112                     http://dianalandia.tumblr.com/       eurosong
# 113                   http://olympusrox123.tumblr.com/       eurosong
# 114                  http://fairyplisetsky.tumblr.com/       eurosong
# 115                 http://embracetheslash.tumblr.com/       eurosong
# 116                         http://hyyteli.tumblr.com/       eurosong
# 117                     http://jade-sanban.tumblr.com/       eurosong
# 118                   http://thejediviking.tumblr.com/       eurosong
# 119                           http://rupko.tumblr.com/       eurosong
# 120                   https://dreamcrazyel.tumblr.com/       eurosong
# 121                       https://siannjay.tumblr.com/       eurosong
# 122                          http://biazhy.tumblr.com/       eurosong
#
#                               Source URL    Comment  Reblog  Like
# 0           http://arabela25.tumblr.com/       None       1     0
# 1    https://mapsontheweb.zoom-maps.com/       None       1     0
# 2          http://clickthing.tumblr.com/       None       1     0
# 3    https://mapsontheweb.zoom-maps.com/       None       1     1
# 4    https://mapsontheweb.zoom-maps.com/       None       1     0
# 5    https://mapsontheweb.zoom-maps.com/       None       1     0
# 6    https://mapsontheweb.zoom-maps.com/       None       1     0
# 7    https://mapsontheweb.zoom-maps.com/   @ph0220        1     1
# 8    https://mapsontheweb.zoom-maps.com/       None       1     1
# 9            http://eurosong.tumblr.com/       None       1     1
# 10   https://mapsontheweb.zoom-maps.com/       None       1     0
# 11   https://mapsontheweb.zoom-maps.com/       None       1     0
# 12      http://alvaroarbeloa.tumblr.com/       None       1     0
# 13           http://eurosong.tumblr.com/       None       1     1
# 14           http://eurosong.tumblr.com/       None       1     1
# 15   https://mapsontheweb.zoom-maps.com/       None       1     0
# 16   https://mapsontheweb.zoom-maps.com/       None       1     1
# 17           http://imarwood.tumblr.com/       None       1     0
# 18   https://mapsontheweb.zoom-maps.com/       None       1     0
# 19   https://mapsontheweb.zoom-maps.com/       None       1     0
# 20   https://mapsontheweb.zoom-maps.com/       None       1     1
# 21   https://mapsontheweb.zoom-maps.com/       None       1     0
# 22   https://mapsontheweb.zoom-maps.com/       None       1     0
# 23   https://mapsontheweb.zoom-maps.com/       None       1     1
# 24   https://mapsontheweb.zoom-maps.com/       None       1     0
# 25   https://mapsontheweb.zoom-maps.com/       None       1     0
# 26   https://mapsontheweb.zoom-maps.com/       None       1     0
# 27   https://mapsontheweb.zoom-maps.com/       None       1     0
# 28   https://mapsontheweb.zoom-maps.com/       None       1     0
# 29           http://eurosong.tumblr.com/       None       1     0
# ..                                   ...        ...     ...   ...
# 93           http://eurosong.tumblr.com/                  0     1
# 94           http://eurosong.tumblr.com/                  0     1
# 95           http://eurosong.tumblr.com/                  0     1
# 96           http://eurosong.tumblr.com/                  0     1
# 97           http://eurosong.tumblr.com/                  0     1
# 98           http://eurosong.tumblr.com/                  0     1
# 99           http://eurosong.tumblr.com/                  0     1
# 100          http://eurosong.tumblr.com/                  0     1
# 101          http://eurosong.tumblr.com/                  0     1
# 102          http://eurosong.tumblr.com/                  0     1
# 103          http://eurosong.tumblr.com/                  0     1
# 104          http://eurosong.tumblr.com/                  0     1
# 105          http://eurosong.tumblr.com/                  0     1
# 106          http://eurosong.tumblr.com/                  0     1
# 107          http://eurosong.tumblr.com/                  0     1
# 108          http://eurosong.tumblr.com/                  0     1
# 109          http://eurosong.tumblr.com/                  0     1
# 110          http://eurosong.tumblr.com/                  0     1
# 111          http://eurosong.tumblr.com/                  0     1
# 112          http://eurosong.tumblr.com/                  0     1
# 113          http://eurosong.tumblr.com/                  0     1
# 114          http://eurosong.tumblr.com/                  0     1
# 115          http://eurosong.tumblr.com/                  0     1
# 116          http://eurosong.tumblr.com/                  0     1
# 117          http://eurosong.tumblr.com/                  0     1
# 118          http://eurosong.tumblr.com/                  0     1
# 119          http://eurosong.tumblr.com/                  0     1
# 120          http://eurosong.tumblr.com/                  0     1
# 121          http://eurosong.tumblr.com/                  0     1
# 122          http://eurosong.tumblr.com/                  0     1
#
# [123 rows x 7 columns]

# %%
columns = ["Recipent URL", "Source URL"]
df_network.drop(columns, inplace=True, axis=1)

# %%
df_networkshort = df_network.reindex_axis(["Comment","Reblog", "Like", "Recipent User", "Source User"], axis=1)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 5):
    display(df_networkshort)
# Out:
#        Comment  Reblog  Like                    Recipent User    Source User
# 0         None       1     0                  iriaowillwinesc      arabela25
# 1         None       1     0                      xiithdoctor   mapsontheweb
# 2         None       1     0                    adventurenerd     clickthing
# 3         None       1     1                     slenderboobs   mapsontheweb
# 4         None       1     0  wherethefuckdidthisshitcomefrom   mapsontheweb
# 5         None       1     0             magrittesflamingtuba   mapsontheweb
# 6         None       1     0         thatdysfunctionalkingdom   mapsontheweb
# 7     @ph0220        1     1                monterrang-parkin   mapsontheweb
# 8         None       1     1                   wymanthewalrus   mapsontheweb
# 9         None       1     1      alwaysfriedstudent-b07d5fd2       eurosong
# 10        None       1     0                       clickthing   mapsontheweb
# 11        None       1     0            canidecideonthislater   mapsontheweb
# 12        None       1     0                       kingkeylor  alvaroarbeloa
# 13        None       1     1                         mmarieto       eurosong
# 14        None       1     1                   portugalpirate       eurosong
# 15        None       1     0                    alvaroarbeloa   mapsontheweb
# 16        None       1     1                     duksisdarker   mapsontheweb
# 17        None       1     0                     gotchipoints       imarwood
# 18        None       1     0            givememorepeaceplease   mapsontheweb
# 19        None       1     0              musicbuttonsandcake   mapsontheweb
# 20        None       1     1                         imarwood   mapsontheweb
# 21        None       1     0                          lxchlxn   mapsontheweb
# 22        None       1     0            weatherwax-poetically   mapsontheweb
# 23        None       1     1                     heirofavians   mapsontheweb
# 24        None       1     0            a-promise-that-i-keep   mapsontheweb
# 25        None       1     0              foreverdrunkatheart   mapsontheweb
# 26        None       1     0                          gandtea   mapsontheweb
# 27        None       1     0                           zazial   mapsontheweb
# 28        None       1     0                 carly-gay-jepsen   mapsontheweb
# 29        None       1     0                     mapsontheweb       eurosong
# 30        None       1     0                saunteringvaguely       eurosong
# 31        None       1     0                         bracarvs       eurosong
# 32        None       1     1              theportugueserevert       eurosong
# 33        None       1     0          every-good-url-is-taken      arabela25
# 34        None       1     1              literallynotcoolirl       eurosong
# 35        None       1     0                       kseniazhuk       eurosong
# 36        None       1     1                 deathatintervals       eurosong
# 37        None       1     0                        arabela25       eurosong
# 38                   0     1              notacolorfullesbian       eurosong
# 39                   0     1                     adelina-popa       eurosong
# 40                   0     1        myanarchistproseandpoetry       eurosong
# 41                   0     1        super-rami-malek-imagines       eurosong
# 42                   0     1                        danasolez       eurosong
# 43                   0     1                    paramarketing       eurosong
# 44                   0     1                      theoldcrone       eurosong
# 45                   0     1                   brendabelanger       eurosong
# 46                   0     1                      wendijordan       eurosong
# 47                   0     1                        subgoogle       eurosong
# 48                   0     1                potatoesrule4ever       eurosong
# 49                   0     1                       tassledown       eurosong
# 50                   0     1                         linamory       eurosong
# 51                   0     1                       dorkynanni       eurosong
# 52                   0     1                       mrfarfalle       eurosong
# 53                   0     1                    claudiopompeo       eurosong
# 54                   0     1                      sidsloth101       eurosong
# 55                   0     1                        hbbannana       eurosong
# 56                   0     1                scandalous-embryo       eurosong
# 57                   0     1                         wrdsmyth       eurosong
# 58                   0     1                        green-217       eurosong
# 59                   0     1                      meridok-old       eurosong
# 60                   0     1                ania-traveler-blr       eurosong
# 61                   0     1                      lowkeylazie       eurosong
# 62                   0     1                   thecakeinspace       eurosong
# 63                   0     1                          icylyly       eurosong
# 64                   0     1                  corvid-shmorvid       eurosong
# 65                   0     1                      planet-noah       eurosong
# 66                   0     1                     swimmingweeb       eurosong
# 67                   0     1                       lanceprime       eurosong
# 68                   0     1                     beifonglover       eurosong
# 69                   0     1                     obliviousxiv       eurosong
# 70                   0     1                        gandoilfo       eurosong
# 71                   0     1                         eurosong       eurosong
# 72                   0     1                       damnsameen       eurosong
# 73                   0     1                      ohlandeskog       eurosong
# 74                   0     1    max-armentas-random-ramblings       eurosong
# 75                   0     1                           cyrren       eurosong
# 76                   0     1                       rhartist13       eurosong
# 77                   0     1                       rivster101       eurosong
# 78                   0     1                         vivillon       eurosong
# 79                   0     1                     randomheresy       eurosong
# 80                   0     1                    mayrose-amica       eurosong
# 81                   0     1            a-plethora-of-reasons       eurosong
# 82                   0     1                garfothedestroyer       eurosong
# 83                   0     1                          mobeika       eurosong
# 84                   0     1                       look-ahead       eurosong
# 85                   0     1                         kitycat1       eurosong
# 86                   0     1                        gaynozomi       eurosong
# 87                   0     1            unintimidablystubborn       eurosong
# 88                   0     1                bitchyhideoutking       eurosong
# 89                   0     1                      kaparaonyou       eurosong
# 90                   0     1                        bumeliran       eurosong
# 91                   0     1     ambitionmissionplusvisionkid       eurosong
# 92                   0     1               saltedcaramelqueer       eurosong
# 93                   0     1                      methoddrone       eurosong
# 94                   0     1                   cookiesandhugs       eurosong
# 95                   0     1                    wolfofromania       eurosong
# 96                   0     1                        shamstack       eurosong
# 97                   0     1                         moe-thot       eurosong
# 98                   0     1                         eurosong       eurosong
# 99                   0     1                 climate-changing       eurosong
# 100                  0     1                       schniggles       eurosong
# 101                  0     1                  daisynightshade       eurosong
# 102                  0     1          a-lost-boy-of-neverland       eurosong
# 103                  0     1                    latinateoaths       eurosong
# 104                  0     1                      thundergyra       eurosong
# 105                  0     1        endlessly-dreaming-of-you       eurosong
# 106                  0     1                        str8busta       eurosong
# 107                  0     1                        klaassein       eurosong
# 108                  0     1                            fs842       eurosong
# 109                  0     1                     wobblywobbly       eurosong
# 110                  0     1                  snifelisnifsnif       eurosong
# 111                  0     1                       pearlyblue       eurosong
# 112                  0     1                      dianalandia       eurosong
# 113                  0     1                    olympusrox123       eurosong
# 114                  0     1                   fairyplisetsky       eurosong
# 115                  0     1                  embracetheslash       eurosong
# 116                  0     1                          hyyteli       eurosong
# 117                  0     1                      jade-sanban       eurosong
# 118                  0     1                    thejediviking       eurosong
# 119                  0     1                            rupko       eurosong
# 120                  0     1                     dreamcrazyel       eurosong
# 121                  0     1                         siannjay       eurosong
# 122                  0     1                           biazhy       eurosong
